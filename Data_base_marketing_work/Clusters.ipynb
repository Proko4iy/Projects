# %%
import pandas as pd

# %%
df=pd.read_excel('cluster_0.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           0   61          1  1178         0.5072
# 1           0   55          1  1159         0.5072
# 2           0   61          1  1134         0.5072
# 3           0   62          1  1183         0.5072
# 4           0   41          1  1157         0.5072
# ...       ...  ...        ...   ...            ...
# 14984       0   64          1  1188         0.5072
# 14985       0   51          1  1134         0.5072
# 14986       0   37          1  1188         0.5072
# 14987       1   42          1  1206         0.5072
# 14988       0   39          1  1134         0.5072
#
#                                            product          colour  cost  \
# 0         Брюки мужские Columbia Rapid Rivers Pant           серый  3439
# 1       Слипоны мужские Skechers Bounder Vertville           синий  2999
# 2              Куртка утепленная женская Northland        болотный  5849
# ...

# %%
df=pd.read_excel('cluster_1.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           1   30          1  1188         0.4304
# 1           1   36          1  1134         0.4304
# 2           1   56          1  1152         0.4304
# 3           1   46          1  1202         0.4304
# 4           1   46          1  1134         0.4304
# ...       ...  ...        ...   ...            ...
# 14249       1   49          1  1160         0.4304
# 14250       1   41          1  1183         0.4304
# 14251       1   61          1  1178         0.4304
# 14252       1   41          1  1168         0.4304
# 14253       1   63          1  1147         0.4304
#
#                                              product                 colour  \
# 0            Замок велосипедный ABUS Catena 6806K/75                  синий
# 1             Бутсы мужские Demix Armando Leather TF                 чёрный
# 2                             Ветровка мужская Demix            темно-синий
# ...

# %%
df=pd.read_excel('cluster_2.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           1   35          1  1134         0.4304
# 1           1   38          1  1162         0.4304
# 2           1   40          1  1199         0.4304
# 3           1   31          1  1134         0.4304
# 4           1   50          1  1187         0.4304
# ...       ...  ...        ...   ...            ...
# 15799       1   37          1  1204         0.4304
# 15800       1   41          1  1188         0.4304
# 15801       1   38          1  1188         0.4304
# 15802       1   35          1  1208         0.4304
# 15803       1   45          1  1177         0.4304
#
#                                                  product             colour  \
# 0                             Обруч гимнастический Demix              серый
# 1                                 Футболка мужская Demix             черный
# 2      Внешний аккумулятор INTERSTEP 10 000 мАч, micr...            красный
# ...

# %%
df=pd.read_excel('cluster_3.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           0   26          0  1160         0.5584
# 1           1   20          0  1134         0.4688
# 2           0   22          0  1174         0.5584
# 3           1   22          0  1192         0.4688
# 4           1   20          0  1134         0.4688
# ...       ...  ...        ...   ...            ...
# 15194       1   25          0  1162         0.4688
# 15195       1   19          0  1204         0.4688
# 15196       0   26          0  1198         0.5584
# 15197       1   23          0  1134         0.4688
# 15198       1   25          0  1202         0.4688
#
#                                                product        colour   cost  \
# 0                                 Легинсы женские FILA    фиолетовый    849
# 1                   Шорты мужские Nike Dri-FIT Academy  черный/белый   2299
# 2                                 Брюки женские adidas        черный   2799
# ...

# %%
df=pd.read_excel('cluster_4.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           0   53          1  1134         0.5072
# 1           0   41          1  1188         0.5072
# 2           0   34          1  1134         0.5072
# 3           0   40          1  1134         0.5072
# 4           0   36          1  1134         0.5072
# ...       ...  ...        ...   ...            ...
# 10719       1   35          1  1157         0.5072
# 10720       0   46          1  1192         0.5072
# 10721       0   35          1  1202         0.5072
# 10722       0   32          1  1134         0.5072
# 10723       0   43          1  1134         0.5072
#
#                                             product          colour  cost  \
# 0                        Чехол для 1 ракетки Torneo           синий   419
# 1      Палатка 3-местная Outventure 1 Second Tent 3   темно-зелёный  8999
# 2                          Шорты мужские Outventure     темно-синий  2699
# ...

# %%
df=pd.read_excel('cluster_5.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           1   49          1  1134         0.4304
# 1           1   38          1  1168         0.5072
# 2           1   46          1  1194         0.4304
# 3           1   30          1  1201         0.4304
# 4           1   29          1  1134         0.4304
# ...       ...  ...        ...   ...            ...
# 14732       1   33          1  1203         0.4304
# 14733       1   38          1  1191         0.4304
# 14734       1   37          1  1161         0.4304
# 14735       1   55          1  1134         0.4304
# 14736       1   39          1  1188         0.4304
#
#                                                  product  \
# 0                      Кроссовки мужские Demix Compact 5
# 1        Футболка мужская Quiksilver Sunset Logo Flaxton
# 2      Нож Adimanti by Ganzo (Skimen design) оранжевы...
# 3                                 Футболка мужская Demix
# 4               Полуботинки мужские Outventure Discovery
# ...

# %%
df=pd.read_excel('cluster_6.xlsx')

# %%
df
# Out:
#        gender  age  education  city  personal_coef  \
# 0           0   29          1  1188         0.5072
# 1           0   43          1  1183         0.5072
# 2           0   30          1  1162         0.5072
# 3           0   37          1  1134         0.5072
# 4           0   60          1  1134         0.5072
# ...       ...  ...        ...   ...            ...
# 14288       0   48          1  1188         0.5072
# 14289       0   30          1  1156         0.5072
# 14290       0   32          1  1159         0.5072
# 14291       1   35          1  1188         0.5072
# 14292       0   55          1  1179         0.5072
#
#                                       product          colour  cost  \
# 0      Сандалии женские Skechers D'Lux Walker          черный  3149
# 1                    Майка для девочек Termit         розовый   699
# 2                         Брюки женские Demix          черный  1749
# 3                         Шорты женские Demix          черный  2299
# ...
